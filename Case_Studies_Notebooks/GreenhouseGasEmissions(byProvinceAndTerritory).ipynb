# %% [markdown]
# ![alt text](https://github.com/callysto/callysto-sample-notebooks/blob/master/notebooks/images/Callysto_Notebook-Banner_Top_06.06.18.jpg?raw=true)

# %% [markdown]
# ## Case Study: Greenhouse gas emissions, by province and territory (1990, 2005, 2017)
#
# Greenhouse gas emissions – Greenhouse gas emissions by province and territory, Canada
#
# Geography: Canada, Provinces and Territories of
#
# Source
#
# Open Government Data
#
# https://open.canada.ca/data/en/dataset/9a673fa1-22af-41c1-9ae5-de38de714c83

# %%
# # Download data 
# DATA SET PRODUCT ID  for internal use only. 
import pandas as pd
link = "https://www.canada.ca/content/dam/eccc/documents/csv/cesindicators/ghg-emissions/2019/GHG-emissions-province-en.csv"
df_less2 = pd.read_csv(link)
df_less2 = df_less2.dropna(how='all')
prov_df = df_less2.iloc[:-3]
new_header = prov_df.iloc[0]
data_df = prov_df.iloc[1:]
data_df.columns = new_header
data_df = data_df.fillna(0)
data_df = data_df.replace({'1.6[A]': "1.6"})

# %%
data_df.iloc[:,1:]= data_df.iloc[:,1:].astype(float)

# %%
data_df = data_df.set_index("Province or territory")

# %%
data_df
# Out:
# 1                              1990 greenhouse gas emissions (megatonnes of carbon dioxide equivalent)  \
# Province or territory
# Newfoundland and Labrador (NL)                                                9.4
# Prince Edward Island (PE)                                                     1.9
# Nova Scotia (NS)                                                             19.6
# New Brunswick (NB)                                                           16.1
# Quebec (QC)                                                                  86.1
# Ontario (ON)                                                                  180
# Manitoba (MB)                                                                18.3
# Saskatchewan (SK)                                                            44.4
# Alberta (AB)                                                                172.6
# British Columbia (BC)                                                        51.6
# Yukon (YT)                                                                    0.5
# Northwest Territories (NT)                                                    1.6
# Nunavut (NU)                                                                    0
#
# 1                              2005 greenhouse gas emissions (megatonnes of carbon dioxide equivalent)  \
# Province or territory
# Newfoundland and Labrador (NL)                                                9.9
# Prince Edward Island (PE)                                                       2
# Nova Scotia (NS)                                                             23.2
# New Brunswick (NB)                                                             20
# Quebec (QC)                                                                  86.5
# Ontario (ON)                                                                203.9
# Manitoba (MB)                                                                20.1
# Saskatchewan (SK)                                                              68
# Alberta (AB)                                                                231.1
# British Columbia (BC)                                                        63.1
# Yukon (YT)                                                                    0.5
# Northwest Territories (NT)                                                    1.6
# Nunavut (NU)                                                                  0.4
#
# 1                              2017 greenhouse gas emissions (megatonnes of carbon dioxide equivalent)
# Province or territory
# Newfoundland and Labrador (NL)                                               10.5
# Prince Edward Island (PE)                                                     1.8
# Nova Scotia (NS)                                                             15.6
# New Brunswick (NB)                                                           14.3
# Quebec (QC)                                                                    78
# Ontario (ON)                                                                158.7
# Manitoba (MB)                                                                21.7
# Saskatchewan (SK)                                                            77.9
# Alberta (AB)                                                                272.8
# British Columbia (BC)                                                        62.1
# Yukon (YT)                                                                    0.5
# Northwest Territories (NT)                                                    1.3
# Nunavut (NU)                                                                  0.6

# %%
import matplotlib.pyplot as plt
data_df.plot(kind='bar',figsize=(19,10),use_index=True,grid=True);
plt.xlabel('Province',fontsize=15);
plt.ylabel('Megatonnes of carbon dioxide equivalent',fontsize=15);
plt.title("Greenhouse gas emissions by province and territory, Canada, 1990, 2005 and 2017",fontsize=20);

# %%
data_df.plot(kind='box',figsize=(19,10),use_index=True,grid=True,rot=90);
plt.xlabel('Year',fontsize=15);
plt.ylabel('Megatonnes of carbon dioxide equivalent',fontsize=15);
plt.title("Greenhouse gas emissions by province and territory, Canada, 1990, 2005 and 2017",fontsize=20);

# %%
link2 = "https://www.canada.ca/content/dam/eccc/documents/csv/cesindicators/ghg-emissions/2019/GHG-emissions-sector-en.csv"
greenhouse_sector = pd.read_csv(link2)
greenhouse_sector = greenhouse_sector.dropna()

# %%
new_head = greenhouse_sector.iloc[0]
greenhouse_sector = greenhouse_sector.iloc[1:]
greenhouse_sector.columns = new_head

# %%
greenhouse_sector = greenhouse_sector.set_index("Year")

# %%
greenhouse_sector
# Out:
# 1    Oil and gas (megatonnes of carbon dioxide equivalent)  \
# Year
# 1990                                                106
# 1991                                                104
# 1992                                                113
# 1993                                                121
# 1994                                                125
# 1995                                                132
# 1996                                                139
# 1997                                                140
# 1998                                                145
# 1999                                                154
# 2000                                                157
# 2001                                                158
# 2002                                                161
# 2003                                                163
# 2004                                                162
# 2005                                                158
# 2006                                                161
# 2007                                                168
# 2008                                                160
# 2009                                                158
# 2010                                                159
# 2011                                                165
# 2012                                                176
# 2013                                                186
# 2014                                                193
# 2015                                                192
# 2016                                                187
# 2017                                                195
#
# 1    Transportation (megatonnes of carbon dioxide equivalent)  \
# Year
# 1990                                                122
# 1991                                                116
# 1992                                                117
# 1993                                                118
# 1994                                                122
# 1995                                                123
# 1996                                                127
# 1997                                                132
# 1998                                                139
# 1999                                                144
# 2000                                                146
# 2001                                                148
# 2002                                                149
# 2003                                                154
# 2004                                                159
# 2005                                                162
# 2006                                                163
# 2007                                                167
# 2008                                                167
# 2009                                                164
# 2010                                                170
# 2011                                                170
# 2012                                                172
# 2013                                                175
# 2014                                                173
# 2015                                                174
# 2016                                                174
# 2017                                                174
#
# 1    Buildings (megatonnes of carbon dioxide equivalent)  \
# Year
# 1990                                                 74
# 1991                                                 73
# 1992                                                 75
# 1993                                                 79
# 1994                                                 79
# 1995                                                 80
# 1996                                                 86
# 1997                                                 83
# 1998                                                 76
# 1999                                                 79
# 2000                                                 86
# 2001                                                 82
# 2002                                                 87
# 2003                                                 92
# 2004                                                 90
# 2005                                                 86
# 2006                                                 81
# 2007                                                 87
# 2008                                                 86
# 2009                                                 85
# 2010                                                 82
# 2011                                                 87
# 2012                                                 86
# 2013                                                 86
# 2014                                                 88
# 2015                                                 86
# 2016                                                 82
# 2017                                                 85
#
# 1    Electricity (megatonnes of carbon dioxide equivalent)  \
# Year
# 1990                                                 94
# 1991                                                 96
# 1992                                                102
# 1993                                                 93
# 1994                                                 95
# 1995                                                 98
# 1996                                                 98
# 1997                                                109
# 1998                                                122
# 1999                                                119
# 2000                                                129
# 2001                                                130
# 2002                                                123
# 2003                                                127
# 2004                                                120
# 2005                                                119
# 2006                                                114
# 2007                                                119
# 2008                                                110
# 2009                                                 95
# 2010                                                 97
# 2011                                                 88
# 2012                                                 84
# 2013                                                 81
# 2014                                                 78
# 2015                                                 81
# 2016                                                 76
# 2017                                                 74
#
# 1    Heavy industry (megatonnes of carbon dioxide equivalent)  \
# Year
# 1990                                                 97
# 1991                                                 97
# 1992                                                 94
# 1993                                                 93
# 1994                                                 99
# 1995                                                100
# 1996                                                102
# 1997                                                102
# 1998                                                 96
# 1999                                                 94
# 2000                                                 93
# 2001                                                 87
# 2002                                                 89
# 2003                                                 88
# 2004                                                 92
# 2005                                                 87
# 2006                                                 86
# 2007                                                 86
# 2008                                                 84
# 2009                                                 72
# 2010                                                 74
# 2011                                                 81
# 2012                                                 80
# 2013                                                 78
# 2014                                                 78
# 2015                                                 77
# 2016                                                 76
# 2017                                                 73
#
# 1    Agriculture (megatonnes of carbon dioxide equivalent)  \
# Year
# 1990                                                 57
# 1991                                                 58
# 1992                                                 60
# 1993                                                 62
# 1994                                                 65
# 1995                                                 68
# 1996                                                 69
# 1997                                                 70
# 1998                                                 70
# 1999                                                 69
# 2000                                                 70
# 2001                                                 68
# 2002                                                 67
# 2003                                                 70
# 2004                                                 72
# 2005                                                 72
# 2006                                                 70
# 2007                                                 71
# 2008                                                 70
# 2009                                                 68
# 2010                                                 68
# 2011                                                 68
# 2012                                                 70
# 2013                                                 72
# 2014                                                 71
# 2015                                                 71
# 2016                                                 72
# 2017                                                 72
#
# 1    Waste and others (megatonnes of carbon dioxide equivalent)
# Year
# 1990                                                 52
# 1991                                                 50
# 1992                                                 49
# 1993                                                 47
# 1994                                                 49
# 1995                                                 51
# 1996                                                 51
# 1997                                                 51
# 1998                                                 47
# 1999                                                 47
# 2000                                                 49
# 2001                                                 47
# 2002                                                 47
# 2003                                                 47
# 2004                                                 49
# 2005                                                 47
# 2006                                                 46
# 2007                                                 47
# 2008                                                 45
# 2009                                                 41
# 2010                                                 43
# 2011                                                 44
# 2012                                                 42
# 2013                                                 43
# 2014                                                 42
# 2015                                                 42
# 2016                                                 41
# 2017                                                 42

# %%
greenhouse_sector = greenhouse_sector.astype(float)

# %%
greenhouse_sector.plot(kind="box",figsize=(19,10),grid=True,rot=90);

# %%
greenhouse_sector.plot(kind="bar",figsize=(19,10),grid=True,rot=90);
plt.xlabel("Year");
plt.ylabel("Megatonnes of carbon dioxide equivalent");
plt.title("Greenhouse gas emissions (by sector (1990 - 2017))");

# %% [markdown]
# ![alt text](https://github.com/callysto/callysto-sample-notebooks/blob/master/notebooks/images/Callysto_Notebook-Banners_Bottom_06.06.18.jpg?raw=true)
