# %% [markdown]
# ![alt text](https://github.com/callysto/callysto-sample-notebooks/blob/master/notebooks/images/Callysto_Notebook-Banner_Top_06.06.18.jpg?raw=true)

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# Download data
link_to_database_data = "http://cdd.publicsafety.gc.ca/dl-eng.aspx?cultureCode=en-Ca&normalizedCostYear=1"
# Load data as dataframe
disaster_pd = pd.read_csv(link_to_database_data,sep="\t")
# Extract subset of the data with information on wildfires
wildfire_pd = disaster_pd[disaster_pd["EVENT TYPE"]=="Wildfire"]

# %%
# Data cleanup - remove columns not relevant for case study
wildfire_pd = wildfire_pd.drop(['FEDERAL DFAA PAYMENTS',
       'PROVINCIAL DFAA PAYMENTS', 'PROVINCIAL DEPARTMENT PAYMENTS',
       'MUNICIPAL COSTS', 'OGD COSTS', 'INSURANCE PAYMENTS', 'NGO PAYMENTS',
       'UTILITY - PEOPLE AFFECTED', 'MAGNITUDE', 'Unnamed: 22'], axis=1)

# %%
wildfire_pd.columns
# Out:
# Index(['EVENT CATEGORY', 'EVENT GROUP', 'EVENT SUBGROUP', 'EVENT TYPE',
#        'PLACE', 'EVENT START DATE', 'COMMENTS', 'FATALITIES',
#        'INJURED / INFECTED', 'EVACUATED', 'ESTIMATED TOTAL COST',
#        'NORMALIZED TOTAL COST', 'EVENT END DATE'],
#       dtype='object')

# %%
#pd.to_datetime(wildfire_pd["EVENT START DATE"])

# %%
import matplotlib.pyplot as plt

# %%
place = wildfire_pd[wildfire_pd["PLACE"].str.contains("ON")]

# %%
place.plot.bar(x="EVENT START DATE",y="EVACUATED")

# %%
wildfire_pd.columns
# Out:
# Index(['EVENT CATEGORY', 'EVENT GROUP', 'EVENT SUBGROUP', 'EVENT TYPE',
#        'PLACE', 'EVENT START DATE', 'COMMENTS', 'FATALITIES',
#        'INJURED / INFECTED', 'EVACUATED', 'ESTIMATED TOTAL COST',
#        'NORMALIZED TOTAL COST', 'EVENT END DATE'],
#       dtype='object')

# %%
place["PLACE"].str.findall(r'[A-Z]').str.len()
# Out:
# 27       3
# 43       4
# 78       4
# 263      3
# 266      7
# 302      3
# 356     21
# 549      3
# 558      3
# 604      6
# 609      3
# 632      3
# 873      4
# 965      4
# 985      8
# 1003     4
# 1012     3
# 1019     6
# Name: PLACE, dtype: int64

# %%
place
# Out:
#      EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP EVENT TYPE  \
# 27         Disaster     Natural  Meteorological - Hydrological   Wildfire
# 43         Disaster     Natural  Meteorological - Hydrological   Wildfire
# 78         Disaster     Natural  Meteorological - Hydrological   Wildfire
# 263        Disaster     Natural  Meteorological - Hydrological   Wildfire
# 266        Disaster     Natural  Meteorological - Hydrological   Wildfire
# 356   Kee-Way-Win FN; Townships of Terrace Bay and S...         0.0
# 549   Chapleau ON, May 27, 2010. A forest fire, whic...         0.0
# 558   Haileybury and northern region ON, September 3...        43.0
# 604   Dance Township ON, October 10-15, 1938; 17 dea...        17.0
# 609   Gogama ON, May 14 - June 15, 1941. No dead, 13...         0.0
# 632   Mississagi/Chapleau (a First Nation reserve) O...         0.0
# 873   Red Lake ON, June 1980. 43,664.76 ha of forest...         0.0
# 965   Valrita-Harty ON, 1987. Entire village of 800 ...         0.0
# 985   Mishkeegogamang Ojibway First Nation (New Osna...         NaN
# 1003  Kirkland Lake ON, May 20-29, 2012. A wildfire ...         0.0
# 1012  Timmins ON, May 24 to June 07, 2012. A state o...         0.0
# 1019  Sandy Lake ON, July 31 to August 6, 2012. The ...         0.0
#
#       INJURED / INFECTED  EVACUATED  ESTIMATED TOTAL COST  \
# 27                   0.0      200.0                   NaN
# 43                   0.0     8000.0                   NaN
# 78                   0.0      500.0                   NaN
# 263                  0.0      400.0                   NaN
# 266                  0.0      823.0                   NaN
# 302                  0.0      307.0                   NaN
# 356                  0.0      985.0                   0.0
# 549                  0.0        0.0                   0.0
# 558                  0.0    11000.0                   NaN
# 604                  0.0      155.0                   NaN
# 609                  0.0        0.0                   NaN
# 632                  0.0        0.0                   NaN
# 873                  0.0     5000.0                   NaN
# 965                  0.0      800.0                   NaN
# 985                  NaN      423.0                   0.0
# 1003                 0.0      300.0                   0.0
# 1012                 0.0     1000.0                   0.0
# 1019                 0.0      637.0                   0.0
#
#       NORMALIZED TOTAL COST          EVENT END DATE
# 27                      NaN   7/11/1911 12:00:00 AM
# 43                      NaN   7/29/1916 12:00:00 AM
# 78                      NaN    1/1/1988 12:00:00 AM
# 263                     NaN   5/29/1997 12:00:00 AM
# 266                     NaN   6/12/1997 12:00:00 AM
# 302                     NaN    5/4/1999 12:00:00 AM
# 356                     0.0    7/1/2002 12:00:00 AM
# 549                     0.0   5/27/2010 12:00:00 AM
# 558                     NaN   10/5/1922 12:00:00 AM
# 604                     NaN  10/15/1938 12:00:00 AM
# 609                     NaN   6/15/1941 12:00:00 AM
# 632                     NaN  10/31/1948 12:00:00 AM
# 873                     NaN    6/1/1980 12:00:00 AM
# 965                     NaN   5/13/1987 12:00:00 AM
# 985                     0.0   6/27/2011 12:00:00 AM
# 1003                    0.0   5/29/2012 12:00:00 AM
# 1012                    0.0    6/7/2012 12:00:00 AM
# 1019                    0.0    8/6/2012 12:00:00 AM

# %% [markdown]
# ![alt text](https://github.com/callysto/callysto-sample-notebooks/blob/master/notebooks/images/Callysto_Notebook-Banners_Bottom_06.06.18.jpg?raw=true)
